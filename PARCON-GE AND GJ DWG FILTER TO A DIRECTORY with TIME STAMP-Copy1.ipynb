# %% [markdown]
# # PARCON GE AND GJ File List and Copy Elec dwg to a Directory

# %% [markdown]
# # GE AND GJ FILES

# %%
# Import modules
import os
import pandas as pd
import sys
import time
import datetime
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

import numpy as np
from shutil import copyfile
import shutil

# Extract File Name and Rename them to new directory. ro Cad File Print

#################################################################################
# DATA INPUT
### Gathering file list from directories.
# 1. Enter directory name to make a list   : srcdir
# 2. Enter File Saving directory           : file_path_dir
# 3. Enter excel file name to be saved     : filename
# 4. Enter file copy ddestination          : dstdir

srcdir=r"K:\20080264-PARCON\ACAD"
file_path_dir= r"G:\cjang\Working\20080264-Parcon\Drawing\pdf\Combined\PRINT\2024-01-29"
filename="PARCON_GE_GJ_Dwg_2024-01-29.xlsx"
dstdir = r"G:\cjang\Working\20080264-Parcon\Drawing\pdf\Combined\PRINT\2024-01-29"


####################################################################################
# L Drive
# L:\CAD\ELEC\STANDARDDRAWINGS\METRICBORDER\StandardDetails\MOPH1_Electrical_standards
####################################################################################

# %%
# File location and file name
file_path=file_path_dir+"\\"+filename
os.chdir(srcdir)
os.getcwd()

### Create new path or select the path to copy files to
if not os.path.exists(dstdir):
    os.makedirs(dstdir)


filelistfull=[]
filelistonly=[]
filelistdironly=[]
file_NEW=[]

for root, dirs, files in os.walk(srcdir,topdown=False):
    for name in files:
        filenamesfull = os.path.join(root,name)
        filenamesonly = os.path.join(name)
        filenamedirolny = os.path.join(root)
        
        
        filelistfull.append(filenamesfull)
        filelistonly.append(filenamesonly)
        filelistdironly.append(filenamedirolny)
        file_NEW.append("")
        
df1=pd.DataFrame(filelistonly)
df2=pd.DataFrame(file_NEW)
df3=pd.DataFrame(filelistdironly)
df4=pd.DataFrame(filelistfull)

df=pd.concat([df1,df2,df3,df4],axis=1)
df.columns = ['OLD','NEW','File_Directory','File_path']

###-----------Apply if new cad file layout extention to be removed ------------ ###
#  df['NEW']=df['OLD'].str.split('-').str[0] +"-" + df['OLD'].str.split('-').str[1]+"-" + df['OLD'].str.split('-').str[2] + '.pdf'
df['NEW']=df['OLD']
df_gf=df

# %% [markdown]
# # GE - ELECTRICAL DRAWING

# %%
df["Name_Length"]= df["OLD"].str.len()

##### filter only ".dwg" file
# df[df["col"].str.contains("this string")]


vdf = df[df["OLD"].str.contains(".dwg")]  # filter only dwg file
wdf = df[df["OLD"].str.contains("-GE-")]  # filter only dwg file
xdf = df[df["OLD"].str.contains("23")]  # filter only dwg file
ydf = df[df["File_Directory"].str.contains("ELECTRICAL")]  # filter only dwg file

zdf = df.query('Name_Length == 24')

# pd.merge(ydf, zdf)
df1 = pd.merge(vdf,wdf)
df1 = pd.merge(df1,xdf)
df1 = pd.merge(df1,ydf)
df1 = pd.merge(df1,zdf)

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["OLD"].str.contains("x")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("Sketches")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("archive")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("Old")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("OLD")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("Existing")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]
gedf = df1

##########################################################
# gedf = df1 : GE drawing list
# gjdf = df1 : GJ drawing list
# df = pd.merge(gedf,gjdf, how = 'outer', indicator = True)
##########################################################

# %%
gedf
# Out:
#                           OLD                       NEW  \
# 0    23270028-GE-O9161505.dwg  23270028-GE-O9161505.dwg
# 1    23270028-GE-O9161507.dwg  23270028-GE-O9161507.dwg
# 2    23270028-GE-O9161604.dwg  23270028-GE-O9161604.dwg
# 3    23270028-GE-O9161701.dwg  23270028-GE-O9161701.dwg
# 4    23270028-GE-O9161500.dwg  23270028-GE-O9161500.dwg
# ..                        ...                       ...
# 191  23300028-GE-P1860556.dwg  23300028-GE-P1860556.dwg
# 192  23300028-GE-P1860557.dwg  23300028-GE-P1860557.dwg
# 193  23300028-GE-P1860559.dwg  23300028-GE-P1860559.dwg
# 194  23300028-GE-P1860560.dwg  23300028-GE-P1860560.dwg
# 195  23300028-GE-P1860561.dwg  23300028-GE-P1860561.dwg
#
#                                         File_Directory  \
# 0    K:\20080264-PARCON\ACAD\ELECTRICAL\23-BC-0615\...
# 1    K:\20080264-PARCON\ACAD\ELECTRICAL\23-BC-0615\...
# 2    K:\20080264-PARCON\ACAD\ELECTRICAL\23-BC-0615\...
# 3    K:\20080264-PARCON\ACAD\ELECTRICAL\23-BC-0615\...
# ...

# %% [markdown]
# # GJ - INSTRUMENT DRAWING

# %%
##### filter only ".dwg" file
# df[df["col"].str.contains("this string")]


vdf = df[df["OLD"].str.contains("dwg")]  # filter only dwg file
wdf = df[df["OLD"].str.contains("-GJ-")]  # filter only dwg file
xdf = df[df["OLD"].str.contains("23")]  # filter only dwg file
ydf = df[df["File_Directory"].str.contains("Control-Systems")]  # filter only dwg file
zdf = df.query('Name_Length == 24')

# pd.merge(ydf, zdf)
df1 = pd.merge(vdf,wdf)
df1 = pd.merge(df1,xdf)
df1 = pd.merge(df1,ydf)
df1 = pd.merge(df1,zdf)

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("MARKUPS")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("VOID")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("DELSAVE")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("PDF FILES")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("FUTURE WORK")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("Hold")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("Plot")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("plot")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

gjdf = df1
##########################################################
# gedf = df1 : GE drawing list
# gjdf = df1 : GJ drawing list
# df = pd.merge(gedf,gjdf, how = 'outer', indicator = True)
##########################################################

# %%
gjdf
# Out:
#                           OLD                       NEW  \
# 116  23270028-GJ-O9160016.dwg  23270028-GJ-O9160016.dwg
# 117  23270028-GJ-O9160111.dwg  23270028-GJ-O9160111.dwg
# 118  23270028-GJ-O9160014.dwg  23270028-GJ-O9160014.dwg
# 119  23270028-GJ-O9160254.dwg  23270028-GJ-O9160254.dwg
# 120  23270028-GJ-O9160255.dwg  23270028-GJ-O9160255.dwg
# ..                        ...                       ...
# 445  23300028-GJ-P1860510.dwg  23300028-GJ-P1860510.dwg
# 446  23300028-GJ-P1860511.dwg  23300028-GJ-P1860511.dwg
# 447  23200022-GJ-O8590102.dwg  23200022-GJ-O8590102.dwg
# 448  00000000-GJ-00009123.dwg  00000000-GJ-00009123.dwg
# 449  00000000-GJ-00009231.dwg  00000000-GJ-00009231.dwg
#
#                                         File_Directory  \
# 116  K:\20080264-PARCON\ACAD\Control-Systems\GENERA...
# 117  K:\20080264-PARCON\ACAD\Control-Systems\GENERA...
# 118  K:\20080264-PARCON\ACAD\Control-Systems\GENERA...
# 119  K:\20080264-PARCON\ACAD\Control-Systems\GENERA...
# ...

# %% [markdown]
# # GF - P&ID DRAWING

# %%
##### filter only ".dwg" file
# df[df["col"].str.contains("this string")]
df=df_gf
df["Name_Length"]= df["OLD"].str.len()
vdf = df[df["OLD"].str.contains("dwg")]  # filter only dwg file
wdf = df[df["OLD"].str.contains("-GF-")]  # filter only dwg file
xdf = df[df["OLD"].str.contains("02")]  # filter only dwg file
ydf = df[df["File_Directory"].str.contains("PID")]  # filter only dwg file
zdf = df.query('Name_Length == 24')

# pd.merge(ydf, zdf)
df1 = pd.merge(vdf,wdf)
df1 = pd.merge(df1,xdf)
df1 = pd.merge(df1,ydf)
df1 = pd.merge(df1,zdf)

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("For Signature")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("Engr")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("Markups")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("copies")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("VOID")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("Hold")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]

# adf[~adf.x1.isin(bdf.x1)]   x1:OLD
# All rows in adf that do not have a match in bdf.
adf = df1
bdf = df1[df1["File_Directory"].str.contains("Plot")]
df1 = adf[~adf.File_Directory.isin(bdf.File_Directory)]


gfdf = df1
##########################################################
# gedf = df1 : GE drawing list
# gjdf = df1 : GJ drawing list
# df = pd.merge(gedf,gjdf, how = 'outer', indicator = True)
##########################################################

# %%
df1 = pd.merge(gedf,gjdf, how = 'outer')
df2 = pd.merge(df1,gfdf, how = 'outer')
df=df2

# %% [markdown]
# # Export to Excel

# %%
os.chdir(dstdir)
print(os.getcwd())

# Export Dwg file list to the folder as an excel file 
df.to_excel(filename)
os.startfile(filename)
# Out:
# G:\cjang\Working\20080264-Parcon\Drawing\pdf\Combined\PRINT\2024-01-29

# %% [markdown]
# # Copy files to destination directory

# %%
df["OLD_DIR"]=df["File_Directory"]
df["NEW_DIR"]= dstdir

fold = df.OLD.tolist() # converting 'File Name' to list
fnew = df.NEW.tolist() # converting 'Dwg Number' number to list
fodir = df.OLD_DIR.tolist() # converting 'Dwg Number' number to list
fndir = df.NEW_DIR.tolist() # converting 'Dwg Number' number to list

missingfile=[]

i=0

while i < len(fold):
    
    # source file
    srcdir = fodir[i]
    os.chdir(srcdir)
    
    src = srcdir + "\\" + fold[i]
    dst = dstdir + "\\" + fold[i]
    
    try:
#       copyfile(src,dst)
        shutil.copy2(src,dst)
    except:
        missingfilelist=pd.DataFrame(missingfile)  # make a list of missing file name
        pass
    
    i=i+1

# %% [markdown]
# # Time Stamp File List

# %%
# Function
def walk_files(directory_path,excelfilename,excelfilelocation):
    now = datetime.datetime.now()
    print("Start time: ")
    print(str(now))
    
    os.chdir(directory_path)
    print(os.getcwd())
    # Walk through files in directory_path
    filelistfull=[]
    filelistonly=[]
    filelistdironly=[]
    filetimefull=[]    # time
 
    
    for root, dirs, files in os.walk(directory_path,topdown=False):
        for name in files:
            filenamesfull = os.path.join(root,name)
            filenamesonly = os.path.join(name)
            filenamedirolny = os.path.join(root)

            ti_m = os.path.getmtime(filenamesfull)  # time
            # m_ti = time.ctime(ti_m)        # time
            m_ti = time.strftime("%Y %m %d, %H:%M", time.localtime(ti_m))
    
            filelistfull.append(filenamesfull)
            filelistonly.append(filenamesonly)
            filelistdironly.append(filenamedirolny)
            filetimefull.append(m_ti)   # time
            
    df1=pd.DataFrame(filelistfull)
    df2=pd.DataFrame(filelistonly)
    df3=pd.DataFrame(filelistdironly)
    df4=pd.DataFrame(filetimefull)   # time
    
    df=pd.concat([df2,df3,df1,df4],axis=1)    # ,df4
    
    df.columns = ['File_Name','File_Directory','File_path','Time']  #,'Time'
    
    os.chdir(excelfilelocation)
    df.to_excel(excelfilename)
    return df

    
    print ("File list saved in "+ csvfilelocation + "\nFile name: " + csvfilename)

# %%
# def walk_files(directory_path,excelfilename,excelfilelocation):
directory_path = dstdir
excelfilename = "newTime" + filename
excelfilelocation = dstdir

os.chdir(dstdir)
print(os.getcwd())

walk_files(directory_path,excelfilename,excelfilelocation)
os.startfile(excelfilename)
# Out:
# G:\cjang\Working\20080264-Parcon\Drawing\pdf\Combined\PRINT\2024-01-29
# Start time:
# 2024-01-29 09:37:31.166649
# G:\cjang\Working\20080264-Parcon\Drawing\pdf\Combined\PRINT\2024-01-29
